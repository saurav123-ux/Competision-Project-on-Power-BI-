# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("leads_basic_details.csv")
df1
# Out:
#      lead_id  age  gender   current_city current_education  \
# 0    USR1001   16  FEMALE      Hyderabad      Intermediate
# 1    USR1002   20    MALE      Bengaluru            B.Tech
# 2    USR1003   20  FEMALE  Visakhapatnam            B.Tech
# 3    USR1004   16    MALE         Mumbai      Intermediate
# 4    USR1005   16    MALE        Chennai      Intermediate
# ..       ...  ...     ...            ...               ...
# 355  USR1356   21    MALE         Mumbai            Degree
# 356  USR1357   22    MALE        Chennai   Looking for Job
# 357  USR1358   25    MALE        Chennai            B.Tech
# 358  USR1359   18  FEMALE         Mumbai            B.Tech
# 359  USR1360   16    MALE         Mumbai      Intermediate
#
#        parent_occupation  lead_gen_source
# 0       Private Employee     social_media
# 1               Business   user_referrals
# 2                 Lawyer   user_referrals
# 3            IT Employee   user_referrals
# 4    Government Employee   user_referrals
# ..                   ...              ...
# 355  Government Employee   user_referrals
# 356  Government Employee          website
# 357  Government Employee              SEO
# 358  Government Employee  email_marketing
# 359  Government Employee     social_media
#
# [360 rows x 7 columns]

# %%
df2=pd.read_csv("leads_demo_watched_details.csv")
df2
# Out:
#      lead_id demo_watched_date language  watched_percentage
# 0    USR1002          1/4/2022   Telugu                  42
# 1    USR1003          1/7/2022   Telugu                  81
# 2    USR1004          1/2/2022   Telugu                  35
# 3    USR1005          1/3/2022    Hindi                  38
# 4    USR1006         1/12/2022    Hindi                  54
# ..       ...               ...      ...                 ...
# 189  USR1317         2/25/2022  English                  48
# 190  USR1318         2/25/2022  English                  83
# 191  USR1319         2/28/2022  English                  84
# 192  USR1343         1/25/2022  English                  68
# 193  USR1348         2/27/2022  English                  72
#
# [194 rows x 4 columns]

# %%
df3=pd.read_csv("leads_interaction_details.csv")
df3
# Out:
#       jnr_sm_id  lead_id lead_stage call_done_date   call_status  \
# 0     JNR1001MG  USR1001       lead       1/2/2022    successful
# 1     JNR1001MG  USR1001       lead       1/2/2022    successful
# 2     JNR1001MG  USR1002       lead       1/3/2022    successful
# 3     JNR1001MG  USR1002       lead       1/4/2022    successful
# 4     JNR1001MG  USR1002  awareness       1/5/2022    successful
# ...         ...      ...        ...            ...           ...
# 2187  JNR1001MG  USR1356       lead      2/21/2022  unsuccessful
# 2188  JNR1001MG  USR1357       lead       1/8/2022  unsuccessful
# 2189  JNR1001MG  USR1358       lead      1/12/2022  unsuccessful
# 2190  JNR1001MG  USR1359       lead      1/22/2022  unsuccessful
# 2191  JNR1001MG  USR1360       lead      2/21/2022  unsuccessful
#
#              call_reason
# 0      lead_introduction
# 1          demo_schedule
# 2      lead_introduction
# 3          demo_schedule
# 4     post_demo_followup
# ...                  ...
# 2187   lead_introduction
# 2188   lead_introduction
# 2189   lead_introduction
# 2190   lead_introduction
# 2191   lead_introduction
#
# [2192 rows x 6 columns]

# %%
df4=pd.read_csv("leads_reasons_for_no_interest.csv")
df4
# Out:
#      lead_id reasons_for_not_interested_in_demo  \
# 0    USR1001                No time for student
# 1    USR1003                                NaN
# 2    USR1004                                NaN
# 3    USR1005                                NaN
# 4    USR1006                                NaN
# ..       ...                                ...
# 289  USR1356                      Cannot afford
# 290  USR1357                      Cannot afford
# 291  USR1358              Wants offline classes
# 292  USR1359            Will join in final year
# 293  USR1360            Will join in final year
#
#     reasons_for_not_interested_to_consider  \
# 0                                      NaN
# 1                      No time for student
# 2                    Wants offline classes
# 3                             Can't afford
# 4         Student not interested in domain
# ..                                     ...
# 289                                    NaN
# 290                                    NaN
# 291                                    NaN
# 292                                    NaN
# 293                                    NaN
#
#     reasons_for_not_interested_to_convert
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 289                                   NaN
# 290                                   NaN
# 291                                   NaN
# 292                                   NaN
# 293                                   NaN
#
# [294 rows x 4 columns]

# %%
df5=pd.read_csv("sales_managers_assigned_leads_details.csv")
df5
# Out:
#     snr_sm_id  jnr_sm_id assigned_date  cycle  lead_id
# 0    SNR501MG  JNR1001MG      1/1/2022      1  USR1001
# 1    SNR501MG  JNR1001MG      1/1/2022      1  USR1002
# 2    SNR501MG  JNR1001MG      1/1/2022      1  USR1003
# 3    SNR501MG  JNR1001MG      1/1/2022      1  USR1004
# 4    SNR501MG  JNR1001MG      1/1/2022      1  USR1005
# ..        ...        ...           ...    ...      ...
# 355  SNR501MG  JNR1001MG     2/19/2022      4  USR1356
# 356  SNR501MG  JNR1001MG      1/1/2022      1  USR1357
# 357  SNR501MG  JNR1001MG      1/8/2022      2  USR1358
# 358  SNR501MG  JNR1001MG     1/15/2022      3  USR1359
# 359  SNR501MG  JNR1001MG     2/19/2022      4  USR1360
#
# [360 rows x 5 columns]

# %%
m1=pd.merge(df1,df2,on="lead_id")

# %%
m1
# Out:
#      lead_id  age  gender   current_city current_education  \
# 0    USR1002   20    MALE      Bengaluru            B.Tech
# 1    USR1003   20  FEMALE  Visakhapatnam            B.Tech
# 2    USR1004   16    MALE         Mumbai      Intermediate
# 3    USR1005   16    MALE        Chennai      Intermediate
# 4    USR1006   16    MALE          Kochi      Intermediate
# ..       ...  ...     ...            ...               ...
# 189  USR1317   24    MALE         Mumbai   Looking for Job
# 190  USR1318   21    MALE         Mumbai            Degree
# 191  USR1319   22  FEMALE      Bengaluru   Looking for Job
# 192  USR1343   24  FEMALE          Kochi   Looking for Job
# 193  USR1348   16  FEMALE          Kochi      Intermediate
#
#        parent_occupation  lead_gen_source demo_watched_date language  \
# 0               Business   user_referrals          1/4/2022   Telugu
# 1                 Lawyer   user_referrals          1/7/2022   Telugu
# 2            IT Employee   user_referrals          1/2/2022   Telugu
# 3    Government Employee   user_referrals          1/3/2022    Hindi
# 4                 Doctor   user_referrals         1/12/2022    Hindi
# ..                   ...              ...               ...      ...
# 189               Lawyer     social_media         2/25/2022  English
# 190          IT Employee  email_marketing         2/25/2022  English
# 191  Government Employee  email_marketing         2/28/2022  English
# 192          IT Employee     social_media         1/25/2022  English
# 193             Business     social_media         2/27/2022  English
#
#      watched_percentage
# 0                    42
# 1                    81
# 2                    35
# 3                    38
# 4                    54
# ..                  ...
# 189                  48
# 190                  83
# 191                  84
# 192                  68
# 193                  72
#
# [194 rows x 10 columns]

# %%
m2=pd.merge(m1,df3,on="lead_id")
m2
# Out:
#       lead_id  age  gender current_city current_education parent_occupation  \
# 0     USR1002   20    MALE    Bengaluru            B.Tech          Business
# 1     USR1002   20    MALE    Bengaluru            B.Tech          Business
# 2     USR1002   20    MALE    Bengaluru            B.Tech          Business
# 3     USR1002   20    MALE    Bengaluru            B.Tech          Business
# 4     USR1002   20    MALE    Bengaluru            B.Tech          Business
# ...       ...  ...     ...          ...               ...               ...
# 1573  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 1574  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 1575  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 1576  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 1577  USR1348   16  FEMALE        Kochi      Intermediate          Business
#
#      lead_gen_source demo_watched_date language  watched_percentage  \
# 0     user_referrals          1/4/2022   Telugu                  42
# 1     user_referrals          1/4/2022   Telugu                  42
# 2     user_referrals          1/4/2022   Telugu                  42
# 3     user_referrals          1/4/2022   Telugu                  42
# 4     user_referrals          1/4/2022   Telugu                  42
# ...              ...               ...      ...                 ...
# 1573    social_media         2/27/2022  English                  72
# 1574    social_media         2/27/2022  English                  72
# 1575    social_media         2/27/2022  English                  72
# 1576    social_media         2/27/2022  English                  72
# 1577    social_media         2/27/2022  English                  72
#
#       jnr_sm_id     lead_stage call_done_date call_status  \
# 0     JNR1001MG           lead       1/3/2022  successful
# 1     JNR1001MG           lead       1/4/2022  successful
# 2     JNR1001MG      awareness       1/5/2022  successful
# 3     JNR1001MG      awareness       1/6/2022  successful
# 4     JNR1001MG  consideration       1/7/2022  successful
# ...         ...            ...            ...         ...
# 1573  JNR1012MG           lead      2/28/2022  successful
# 1574  JNR1012MG      awareness      2/28/2022  successful
# 1575  JNR1012MG      awareness      2/28/2022  successful
# 1576  JNR1012MG  consideration      2/28/2022  successful
# 1577  JNR1012MG  consideration      2/28/2022  successful
#
#                      call_reason
# 0              lead_introduction
# 1                  demo_schedule
# 2             post_demo_followup
# 3     followup_for_consideration
# 4      interested_for_conversion
# ...                          ...
# 1573           demo_not_attended
# 1574          post_demo_followup
# 1575  followup_for_consideration
# 1576     followup_for_conversion
# 1577   interested_for_conversion
#
# [1578 rows x 15 columns]

# %%
m3=pd.merge(m2,df4,on="lead_id")
m3
# Out:
#      lead_id  age  gender   current_city current_education parent_occupation  \
# 0    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 1    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 2    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 3    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 4    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# ..       ...  ...     ...            ...               ...               ...
# 936  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 937  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 938  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 939  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 940  USR1348   16  FEMALE          Kochi      Intermediate          Business
#
#     lead_gen_source demo_watched_date language  watched_percentage  jnr_sm_id  \
# 0    user_referrals          1/7/2022   Telugu                  81  JNR1001MG
# 1    user_referrals          1/7/2022   Telugu                  81  JNR1001MG
# 2    user_referrals          1/7/2022   Telugu                  81  JNR1001MG
# 3    user_referrals          1/7/2022   Telugu                  81  JNR1001MG
# 4    user_referrals          1/7/2022   Telugu                  81  JNR1001MG
# ..              ...               ...      ...                 ...        ...
# 936    social_media         2/27/2022  English                  72  JNR1012MG
# 937    social_media         2/27/2022  English                  72  JNR1012MG
# 938    social_media         2/27/2022  English                  72  JNR1012MG
# 939    social_media         2/27/2022  English                  72  JNR1012MG
# 940    social_media         2/27/2022  English                  72  JNR1012MG
#
#         lead_stage call_done_date   call_status                 call_reason  \
# 0             lead       1/4/2022  unsuccessful           lead_introduction
# 1             lead       1/5/2022    successful           lead_introduction
# 2             lead       1/7/2022    successful               demo_schedule
# 3        awareness       1/8/2022    successful          post_demo_followup
# 4        awareness       1/9/2022    successful  followup_for_consideration
# ..             ...            ...           ...                         ...
# 936           lead      2/28/2022    successful           demo_not_attended
# 937      awareness      2/28/2022    successful          post_demo_followup
# 938      awareness      2/28/2022    successful  followup_for_consideration
# 939  consideration      2/28/2022    successful     followup_for_conversion
# 940  consideration      2/28/2022    successful   interested_for_conversion
#
#     reasons_for_not_interested_in_demo reasons_for_not_interested_to_consider  \
# 0                                  NaN                    No time for student
# 1                                  NaN                    No time for student
# 2                                  NaN                    No time for student
# 3                                  NaN                    No time for student
# 4                                  NaN                    No time for student
# ..                                 ...                                    ...
# 936                                NaN                                    NaN
# 937                                NaN                                    NaN
# 938                                NaN                                    NaN
# 939                                NaN                                    NaN
# 940                                NaN                                    NaN
#
#     reasons_for_not_interested_to_convert
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 936                 Wants offline classes
# 937                 Wants offline classes
# 938                 Wants offline classes
# 939                 Wants offline classes
# 940                 Wants offline classes
#
# [941 rows x 18 columns]

# %%
df=pd.merge(m3,df5,on="lead_id")
df
# Out:
#      lead_id  age  gender   current_city current_education parent_occupation  \
# 0    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 1    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 2    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 3    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 4    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# ..       ...  ...     ...            ...               ...               ...
# 936  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 937  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 938  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 939  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 940  USR1348   16  FEMALE          Kochi      Intermediate          Business
#
#     lead_gen_source demo_watched_date language  watched_percentage  ...  \
# 0    user_referrals          1/7/2022   Telugu                  81  ...
# 1    user_referrals          1/7/2022   Telugu                  81  ...
# 2    user_referrals          1/7/2022   Telugu                  81  ...
# 3    user_referrals          1/7/2022   Telugu                  81  ...
# 4    user_referrals          1/7/2022   Telugu                  81  ...
# ..              ...               ...      ...                 ...  ...
# 936    social_media         2/27/2022  English                  72  ...
# 937    social_media         2/27/2022  English                  72  ...
# 938    social_media         2/27/2022  English                  72  ...
# 939    social_media         2/27/2022  English                  72  ...
# 940    social_media         2/27/2022  English                  72  ...
#
#     call_done_date   call_status                 call_reason  \
# 0         1/4/2022  unsuccessful           lead_introduction
# 1         1/5/2022    successful           lead_introduction
# 2         1/7/2022    successful               demo_schedule
# 3         1/8/2022    successful          post_demo_followup
# 4         1/9/2022    successful  followup_for_consideration
# ..             ...           ...                         ...
# 936      2/28/2022    successful           demo_not_attended
# 937      2/28/2022    successful          post_demo_followup
# 938      2/28/2022    successful  followup_for_consideration
# 939      2/28/2022    successful     followup_for_conversion
# 940      2/28/2022    successful   interested_for_conversion
#
#     reasons_for_not_interested_in_demo reasons_for_not_interested_to_consider  \
# 0                                  NaN                    No time for student
# 1                                  NaN                    No time for student
# 2                                  NaN                    No time for student
# 3                                  NaN                    No time for student
# 4                                  NaN                    No time for student
# ..                                 ...                                    ...
# 936                                NaN                                    NaN
# 937                                NaN                                    NaN
# 938                                NaN                                    NaN
# 939                                NaN                                    NaN
# 940                                NaN                                    NaN
#
#     reasons_for_not_interested_to_convert snr_sm_id jnr_sm_id_y assigned_date  \
# 0                                     NaN  SNR501MG   JNR1001MG      1/1/2022
# 1                                     NaN  SNR501MG   JNR1001MG      1/1/2022
# 2                                     NaN  SNR501MG   JNR1001MG      1/1/2022
# 3                                     NaN  SNR501MG   JNR1001MG      1/1/2022
# 4                                     NaN  SNR501MG   JNR1001MG      1/1/2022
# ..                                    ...       ...         ...           ...
# 936                 Wants offline classes  SNR503MG   JNR1012MG     2/19/2022
# 937                 Wants offline classes  SNR503MG   JNR1012MG     2/19/2022
# 938                 Wants offline classes  SNR503MG   JNR1012MG     2/19/2022
# 939                 Wants offline classes  SNR503MG   JNR1012MG     2/19/2022
# 940                 Wants offline classes  SNR503MG   JNR1012MG     2/19/2022
#
#     cycle
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 936     4
# 937     4
# 938     4
# 939     4
# 940     4
#
# [941 rows x 22 columns]

# %%
df.shape
# Out:
# (941, 22)

# %%
df.isnull().sum()
# Out:
# lead_id                                   0
# age                                       0
# gender                                    0
# current_city                              0
# current_education                         0
# parent_occupation                         0
# lead_gen_source                           0
# demo_watched_date                         0
# language                                  0
# watched_percentage                        0
# jnr_sm_id_x                               0
# lead_stage                                0
# call_done_date                            0
# call_status                               0
# call_reason                               0
# reasons_for_not_interested_in_demo        0
# reasons_for_not_interested_to_consider    0
# reasons_for_not_interested_to_convert     0
# snr_sm_id                                 0
# jnr_sm_id_y                               0
# assigned_date                             0
# cycle                                     0
# dtype: int64

# %%
df=df.fillna("Not Provided")

# %%
for i in  df.columns:
    print(i)
    print(df[i].unique(),'\n')
# Out:
# lead_id
# ['USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1008' 'USR1009' 'USR1010'
#  'USR1014' 'USR1015' 'USR1016' 'USR1018' 'USR1019' 'USR1020' 'USR1021'
#  'USR1024' 'USR1026' 'USR1027' 'USR1028' 'USR1029' 'USR1030' 'USR1034'
#  'USR1035' 'USR1036' 'USR1038' 'USR1039' 'USR1040' 'USR1041' 'USR1043'
#  'USR1044' 'USR1045' 'USR1046' 'USR1050' 'USR1055' 'USR1058' 'USR1065'
#  'USR1067' 'USR1070' 'USR1071' 'USR1075' 'USR1077' 'USR1078' 'USR1082'
#  'USR1083' 'USR1087' 'USR1090' 'USR1091' 'USR1095' 'USR1097' 'USR1098'
#  'USR1105' 'USR1107' 'USR1110' 'USR1111' 'USR1115' 'USR1117' 'USR1118'
#  'USR1122' 'USR1123' 'USR1127' 'USR1130' 'USR1131' 'USR1135' 'USR1137'
#  'USR1138' 'USR1145' 'USR1147' 'USR1150' 'USR1151' 'USR1155' 'USR1157'
#  'USR1158' 'USR1162' 'USR1163' 'USR1167' 'USR1170' 'USR1171' 'USR1175'
#  'USR1177' 'USR1178' 'USR1185' 'USR1187' 'USR1190' 'USR1191' 'USR1195'
#  'USR1197' 'USR1198' 'USR1202' 'USR1203' 'USR1207' 'USR1210' 'USR1211'
#  'USR1215' 'USR1217' 'USR1218' 'USR1225' 'USR1227' 'USR1230' 'USR1231'
#  'USR1235' 'USR1237' 'USR1238' 'USR1242' 'USR1243' 'USR1247' 'USR1250'
#  'USR1251' 'USR1255' 'USR1257' 'USR1258' 'USR1265' 'USR1267' 'USR1270'
#  'USR1271' 'USR1275' 'USR1277' 'USR1278' 'USR1282' 'USR1283' 'USR1287'
#  'USR1290' 'USR1291' 'USR1295' 'USR1298' 'USR1305' 'USR1310' 'USR1315'
#  'USR1318' 'USR1319' 'USR1343' 'USR1348']
#
# age
# [ 20  16  22  25  18 211  24  21]
#
# gender
# ['FEMALE' 'MALE']
#
# current_city
# ['Visakhapatnam' 'Mumbai' 'Chennai' 'Kochi' 'Hyderabad' 'Bengaluru']
#
# current_education
# ['B.Tech' 'Intermediate' 'Looking for Job' '10th Completed' 'Degree']
#
# parent_occupation
# ['Lawyer' 'IT Employee' 'Government Employee' 'Doctor' 'Business'
#  'Professor/Faculty' 'Private Employee']
#
# lead_gen_source
# ['user_referrals' 'website' 'SEO' 'social_media' 'email_marketing']
#
# demo_watched_date
# ['1/7/2022' '1/2/2022' '1/3/2022' '1/12/2022' '1/8/2022' '1/10/2022'
#  '1/18/2022' '2/21/2022' '2/20/2022' '1/9/2022' '1/11/2022' '1/19/2022'
#  '1/17/2022' '2/25/2022' '1/1/2022' '1/4/2022' '1/6/2022' '2/22/2022'
#  '1/5/2022' '1/20/2022' '2/23/2022' '1/13/2022' '1/16/2022' '1/26/2022'
#  '2/26/2022' '1/14/2022' '2/28/2022' '1/25/2022' '2/27/2022']
#
# language
# ['Telugu' 'Hindi' 'English']
#
# watched_percentage
# [ 81  35  38  54  41  50  48  51  44  47  40  36 100  53  10  11  14  17
#   73  26  29  56  59  62  70  75  85  71  86  89   2  90  74  91  92  63
#   25   3   8  45  65  23 510  60  37  68  49  57  61  80  15  12  13  72
#   27  21  19  16  76  77  20  79  78  22  24  82  83  84]
#
# jnr_sm_id_x
# ['JNR1001MG' 'JNR1002MG' 'JNR1003MG' 'JNR1004MG' 'JNR1005MG' 'JNR1006MG'
#  'JNR1007MG' 'JNR1008MG' 'JNR1009MG' 'JNR1010MG' 'JNR1011MG' 'JNR1012MG'
#  'JNR1013MG' 'JNR1014MG' 'JNR1015MG' 'JNR1016MG']
#
# lead_stage
# ['lead' 'awareness' 'consideration']
#
# call_done_date
# ['1/4/2022' '1/5/2022' '1/7/2022' '1/8/2022' '1/9/2022' '1/1/2022'
#  '1/2/2022' '1/3/2022' '1/10/2022' '1/12/2022' '1/13/2022' '1/11/2022'
#  '1/14/2022' '1/17/2022' '1/18/2022' '1/19/2022' '1/15/2022' '1/16/2022'
#  '1/20/2022' '2/19/2022' '2/21/2022' '2/22/2022' '2/20/2022' '2/23/2022'
#  '2/24/2022' '2/25/2022' '1/6/2022' '1/21/2022' '1/22/2022' '2/26/2022'
#  '1/24/2022' '1/26/2022' '1/27/2022' '1/28/2022' '2/27/2022' '2/28/2022']
#
# call_status
# ['unsuccessful' 'successful']
#
# call_reason
# ['lead_introduction' 'demo_schedule' 'post_demo_followup'
#  'followup_for_consideration' 'demo_not_attended'
#  'interested_for_conversion' 'followup_for_conversion']
#
# reasons_for_not_interested_in_demo
# ['Not Provided']
#
# reasons_for_not_interested_to_consider
# ['No time for student' 'Wants offline classes' "Can't afford"
#  'Student not interested in domain' 'Will join in final year'
#  'Not Provided']
#
# reasons_for_not_interested_to_convert
# ['Not Provided' "Can't afford" 'Will join in final year'
#  'No time for student' 'Student not interested in domain'
#  'Wants offline classes']
#
# snr_sm_id
# ['SNR501MG' 'SNR502MG' 'SNR503MG' 'SNR504MG']
#
# jnr_sm_id_y
# ['JNR1001MG' 'JNR1002MG' 'JNR1003MG' 'JNR1004MG' 'JNR1005MG' 'JNR1006MG'
#  'JNR1007MG' 'JNR1008MG' 'JNR1009MG' 'JNR1010MG' 'JNR1011MG' 'JNR1012MG'
#  'JNR1013MG' 'JNR1014MG' 'JNR1015MG' 'JNR1016MG']
#
# assigned_date
# ['1/1/2022' '1/8/2022' '1/15/2022' '2/19/2022']
#
# cycle
# [1 2 3 4]

# %%
df.dtypes
# Out:
# lead_id                                           object
# age                                                int64
# gender                                            object
# current_city                                      object
# current_education                                 object
# parent_occupation                                 object
# lead_gen_source                                   object
# demo_watched_date                         datetime64[ns]
# language                                          object
# watched_percentage                                 int64
# jnr_sm_id_x                                       object
# lead_stage                                        object
# call_done_date                            datetime64[ns]
# call_status                                       object
# call_reason                                       object
# reasons_for_not_interested_in_demo                object
# reasons_for_not_interested_to_consider            object
# reasons_for_not_interested_to_convert             object
# snr_sm_id                                         object
# jnr_sm_id_y                                       object
# assigned_date                             datetime64[ns]
# cycle                                              int64
# dtype: object

# %%
df['demo_watched_date']=pd.to_datetime(df['demo_watched_date'])

# %%
df['call_done_date']=pd.to_datetime(df['call_done_date'])

# %%
df['assigned_date']=pd.to_datetime(df['assigned_date'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['lead_id', 'age', 'gender', 'current_city', 'current_education',
#        'parent_occupation', 'lead_gen_source', 'demo_watched_date', 'language',
#        'watched_percentage', 'jnr_sm_id_x', 'lead_stage', 'call_done_date',
#        'call_status', 'call_reason', 'reasons_for_not_interested_in_demo',
#        'reasons_for_not_interested_to_consider',
#        'reasons_for_not_interested_to_convert', 'snr_sm_id', 'jnr_sm_id_y',
#        'assigned_date', 'cycle'],
#       dtype='object')

# %%
col=['age','watched_percentage','cycle']

# %%
df['age'].unique()
# Out:
# array([ 20,  16,  22,  25,  18, 211,  24,  21], dtype=int64)

# %%
df['watched_percentage'].unique()
# Out:
# array([ 81,  35,  38,  54,  41,  50,  48,  51,  44,  47,  40,  36, 100,
#         53,  10,  11,  14,  17,  73,  26,  29,  56,  59,  62,  70,  75,
#         85,  71,  86,  89,   2,  90,  74,  91,  92,  63,  25,   3,   8,
#         45,  65,  23, 510,  60,  37,  68,  49,  57,  61,  80,  15,  12,
#         13,  72,  27,  21,  19,  16,  76,  77,  20,  79,  78,  22,  24,
#         82,  83,  84], dtype=int64)

# %%
df['cycle'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
for i in col:
    plt.figure()
    sns.boxplot(y=i,data=df)

# %%
col=['age','watched_percentage']

# %%
for i in col:
    p25=df[i].quantile(0.25)
    p75=df[i].quantile(0.75)
    iqr=p75-p25
    ll=p25-1.5*(iqr)
    ul=p75+1.5*(iqr)
    df=df[df[i]<=ul]
    df=df[df[i]>=ll]
    plt.figure()
    sns.boxplot(y=i,data=df)

# %%
df.shape
# Out:
# (929, 22)

# %%
df
# Out:
#      lead_id  age  gender   current_city current_education parent_occupation  \
# 0    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 1    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 2    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 3    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# 4    USR1003   20  FEMALE  Visakhapatnam            B.Tech            Lawyer
# ..       ...  ...     ...            ...               ...               ...
# 936  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 937  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 938  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 939  USR1348   16  FEMALE          Kochi      Intermediate          Business
# 940  USR1348   16  FEMALE          Kochi      Intermediate          Business
#
#     lead_gen_source demo_watched_date language  watched_percentage  ...  \
# 0    user_referrals        2022-01-07   Telugu                  81  ...
# 1    user_referrals        2022-01-07   Telugu                  81  ...
# 2    user_referrals        2022-01-07   Telugu                  81  ...
# 3    user_referrals        2022-01-07   Telugu                  81  ...
# 4    user_referrals        2022-01-07   Telugu                  81  ...
# ..              ...               ...      ...                 ...  ...
# 936    social_media        2022-02-27  English                  72  ...
# 937    social_media        2022-02-27  English                  72  ...
# 938    social_media        2022-02-27  English                  72  ...
# 939    social_media        2022-02-27  English                  72  ...
# 940    social_media        2022-02-27  English                  72  ...
#
#     call_done_date   call_status                 call_reason  \
# 0       2022-01-04  unsuccessful           lead_introduction
# 1       2022-01-05    successful           lead_introduction
# 2       2022-01-07    successful               demo_schedule
# 3       2022-01-08    successful          post_demo_followup
# 4       2022-01-09    successful  followup_for_consideration
# ..             ...           ...                         ...
# 936     2022-02-28    successful           demo_not_attended
# 937     2022-02-28    successful          post_demo_followup
# 938     2022-02-28    successful  followup_for_consideration
# 939     2022-02-28    successful     followup_for_conversion
# 940     2022-02-28    successful   interested_for_conversion
#
#     reasons_for_not_interested_in_demo reasons_for_not_interested_to_consider  \
# 0                         Not Provided                    No time for student
# 1                         Not Provided                    No time for student
# 2                         Not Provided                    No time for student
# 3                         Not Provided                    No time for student
# 4                         Not Provided                    No time for student
# ..                                 ...                                    ...
# 936                       Not Provided                           Not Provided
# 937                       Not Provided                           Not Provided
# 938                       Not Provided                           Not Provided
# 939                       Not Provided                           Not Provided
# 940                       Not Provided                           Not Provided
#
#     reasons_for_not_interested_to_convert snr_sm_id jnr_sm_id_y assigned_date  \
# 0                            Not Provided  SNR501MG   JNR1001MG    2022-01-01
# 1                            Not Provided  SNR501MG   JNR1001MG    2022-01-01
# 2                            Not Provided  SNR501MG   JNR1001MG    2022-01-01
# 3                            Not Provided  SNR501MG   JNR1001MG    2022-01-01
# 4                            Not Provided  SNR501MG   JNR1001MG    2022-01-01
# ..                                    ...       ...         ...           ...
# 936                 Wants offline classes  SNR503MG   JNR1012MG    2022-02-19
# 937                 Wants offline classes  SNR503MG   JNR1012MG    2022-02-19
# 938                 Wants offline classes  SNR503MG   JNR1012MG    2022-02-19
# 939                 Wants offline classes  SNR503MG   JNR1012MG    2022-02-19
# 940                 Wants offline classes  SNR503MG   JNR1012MG    2022-02-19
#
#     cycle
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 936     4
# 937     4
# 938     4
# 939     4
# 940     4
#
# [929 rows x 22 columns]

# %%
df.to_csv('final_cleaned_data.csv', index=False)
